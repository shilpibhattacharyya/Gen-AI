# %%
pip install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tensorflow
#   Downloading tensorflow-2.15.0-cp39-cp39-macosx_12_0_arm64.whl.metadata (3.6 kB)
# Collecting tensorflow-macos==2.15.0 (from tensorflow)
#   Downloading tensorflow_macos-2.15.0-cp39-cp39-macosx_12_0_arm64.whl.metadata (4.2 kB)
# Collecting absl-py>=1.0.0 (from tensorflow-macos==2.15.0->tensorflow)
#   Downloading absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow-macos==2.15.0->tensorflow)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting flatbuffers>=23.5.26 (from tensorflow-macos==2.15.0->tensorflow)
#   Downloading flatbuffers-23.5.26-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow-macos==2.15.0->tensorflow)
#   Downloading gast-0.5.4-py3-none-any.whl.metadata (1.3 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow-macos==2.15.0->tensorflow)
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 2.3 MB/s eta 0:00:00
# Collecting h5py>=2.9.0 (from tensorflow-macos==2.15.0->tensorflow)
#   Downloading h5py-3.10.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (2.5 kB)
# Collecting libclang>=13.0.0 (from tensorflow-macos==2.15.0->tensorflow)
#   Downloading libclang-16.0.6-py2.py3-none-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Collecting ml-dtypes~=0.2.0 (from tensorflow-macos==2.15.0->tensorflow)
#   Downloading ml_dtypes-0.2.0-cp39-cp39-macosx_10_9_universal2.whl.metadata (20 kB)
# Collecting numpy<2.0.0,>=1.23.5 (from tensorflow-macos==2.15.0->tensorflow)
#   Downloading numpy-1.26.4-cp39-cp39-macosx_11_0_arm64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 7.5 MB/s eta 0:00:00
# Collecting opt-einsum>=2.3.2 (from tensorflow-macos==2.15.0->tensorflow)
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /Users/shilpibhattacharyya/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0->tensorflow) (23.2)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow-macos==2.15.0->tensorflow)
#   Downloading protobuf-4.25.3-cp37-abi3-macosx_10_9_universal2.whl.metadata (541 bytes)
# Requirement already satisfied: setuptools in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow-macos==2.15.0->tensorflow) (58.0.4)
# Requirement already satisfied: six>=1.12.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow-macos==2.15.0->tensorflow) (1.15.0)
# Collecting termcolor>=1.1.0 (from tensorflow-macos==2.15.0->tensorflow)
#   Downloading termcolor-2.4.0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/shilpibhattacharyya/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0->tensorflow) (4.9.0)
# Collecting wrapt<1.15,>=1.11.0 (from tensorflow-macos==2.15.0->tensorflow)
#   Downloading wrapt-1.14.1-cp39-cp39-macosx_11_0_arm64.whl (35 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow-macos==2.15.0->tensorflow)
#   Downloading tensorflow_io_gcs_filesystem-0.36.0-cp39-cp39-macosx_12_0_arm64.whl.metadata (14 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow-macos==2.15.0->tensorflow)
#   Downloading grpcio-1.60.1-cp39-cp39-macosx_10_10_universal2.whl.metadata (4.0 kB)
# Collecting tensorboard<2.16,>=2.15 (from tensorflow-macos==2.15.0->tensorflow)
#   Downloading tensorboard-2.15.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting tensorflow-estimator<2.16,>=2.15.0 (from tensorflow-macos==2.15.0->tensorflow)
#   Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting keras<2.16,>=2.15.0 (from tensorflow-macos==2.15.0->tensorflow)
#   Downloading keras-2.15.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow-macos==2.15.0->tensorflow) (0.37.0)
# Collecting google-auth<3,>=1.6.3 (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow)
#   Downloading google_auth-2.28.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting google-auth-oauthlib<2,>=0.5 (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow)
#   Downloading google_auth_oauthlib-1.2.0-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting markdown>=2.6.8 (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow)
#   Downloading Markdown-3.5.2-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/shilpibhattacharyya/Library/Python/3.9/lib/python/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (2.31.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow)
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow)
#   Downloading werkzeug-3.0.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow)
#   Downloading cachetools-5.3.2-py3-none-any.whl.metadata (5.2 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow)
#   Downloading pyasn1_modules-0.3.0-py2.py3-none-any.whl.metadata (3.6 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow)
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow)
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/shilpibhattacharyya/Library/Python/3.9/lib/python/site-packages (from markdown>=2.6.8->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (7.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/shilpibhattacharyya/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/shilpibhattacharyya/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/shilpibhattacharyya/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/shilpibhattacharyya/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/shilpibhattacharyya/Library/Python/3.9/lib/python/site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (2.1.5)
# Requirement already satisfied: zipp>=0.5 in /Users/shilpibhattacharyya/Library/Python/3.9/lib/python/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (3.17.0)
# Collecting pyasn1<0.6.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow)
#   Downloading pyasn1-0.5.1-py2.py3-none-any.whl.metadata (8.6 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow)
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 5.9 MB/s eta 0:00:00
# Downloading tensorflow-2.15.0-cp39-cp39-macosx_12_0_arm64.whl (2.1 kB)
# Downloading tensorflow_macos-2.15.0-cp39-cp39-macosx_12_0_arm64.whl (208.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.8/208.8 MB 36.9 MB/s eta 0:00:0000:0100:01
# Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.7/133.7 kB 18.5 MB/s eta 0:00:00
# Downloading flatbuffers-23.5.26-py2.py3-none-any.whl (26 kB)
# Downloading gast-0.5.4-py3-none-any.whl (19 kB)
# Downloading grpcio-1.60.1-cp39-cp39-macosx_10_10_universal2.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 56.4 MB/s eta 0:00:00a 0:00:01
# Downloading h5py-3.10.0-cp39-cp39-macosx_11_0_arm64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 49.5 MB/s eta 0:00:00a 0:00:01
# Downloading keras-2.15.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 46.0 MB/s eta 0:00:00
# Downloading libclang-16.0.6-py2.py3-none-macosx_11_0_arm64.whl (20.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.6/20.6 MB 53.9 MB/s eta 0:00:0000:0100:01
# Downloading ml_dtypes-0.2.0-cp39-cp39-macosx_10_9_universal2.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 46.2 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp39-cp39-macosx_11_0_arm64.whl (14.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 51.5 MB/s eta 0:00:00a 0:00:01
# Downloading protobuf-4.25.3-cp37-abi3-macosx_10_9_universal2.whl (394 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 394.2/394.2 kB 25.4 MB/s eta 0:00:00
# Downloading tensorboard-2.15.2-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 52.0 MB/s eta 0:00:00a 0:00:01
# Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl (441 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.0/442.0 kB 39.0 MB/s eta 0:00:00
# Downloading tensorflow_io_gcs_filesystem-0.36.0-cp39-cp39-macosx_12_0_arm64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 51.6 MB/s eta 0:00:00a 0:00:01
# Downloading termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Downloading google_auth-2.28.0-py2.py3-none-any.whl (186 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 186.9/186.9 kB 16.0 MB/s eta 0:00:00
# Downloading google_auth_oauthlib-1.2.0-py2.py3-none-any.whl (24 kB)
# Downloading Markdown-3.5.2-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.9/103.9 kB 11.4 MB/s eta 0:00:00
# Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Downloading werkzeug-3.0.1-py3-none-any.whl (226 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.7/226.7 kB 17.3 MB/s eta 0:00:00
# Downloading cachetools-5.3.2-py3-none-any.whl (9.3 kB)
# Downloading pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 kB 13.5 MB/s eta 0:00:00
# Downloading pyasn1-0.5.1-py2.py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.9/84.9 kB 7.1 MB/s eta 0:00:00
# Installing collected packages: libclang, flatbuffers, wrapt, werkzeug, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, pyasn1, protobuf, oauthlib, numpy, keras, grpcio, google-pasta, gast, cachetools, astunparse, absl-py, rsa, requests-oauthlib, pyasn1-modules, opt-einsum, ml-dtypes, markdown, h5py, google-auth, google-auth-oauthlib, tensorboard, tensorflow-macos, tensorflow
#   WARNING: The script f2py is installed in '/Users/shilpibhattacharyya/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts pyrsa-decrypt, pyrsa-encrypt, pyrsa-keygen, pyrsa-priv2pub, pyrsa-sign and pyrsa-verify are installed in '/Users/shilpibhattacharyya/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script markdown_py is installed in '/Users/shilpibhattacharyya/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script google-oauthlib-tool is installed in '/Users/shilpibhattacharyya/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script tensorboard is installed in '/Users/shilpibhattacharyya/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts estimator_ckpt_converter, import_pb_to_tensorboard, saved_model_cli, tensorboard, tf_upgrade_v2, tflite_convert, toco and toco_from_protos are installed in '/Users/shilpibhattacharyya/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed absl-py-2.1.0 astunparse-1.6.3 cachetools-5.3.2 flatbuffers-23.5.26 gast-0.5.4 google-auth-2.28.0 google-auth-oauthlib-1.2.0 google-pasta-0.2.0 grpcio-1.60.1 h5py-3.10.0 keras-2.15.0 libclang-16.0.6 markdown-3.5.2 ml-dtypes-0.2.0 numpy-1.26.4 oauthlib-3.2.2 opt-einsum-3.3.0 protobuf-4.25.3 pyasn1-0.5.1 pyasn1-modules-0.3.0 requests-oauthlib-1.3.1 rsa-4.9 tensorboard-2.15.2 tensorboard-data-server-0.7.2 tensorflow-2.15.0 tensorflow-estimator-2.15.0 tensorflow-io-gcs-filesystem-0.36.0 tensorflow-macos-2.15.0 termcolor-2.4.0 werkzeug-3.0.1 wrapt-1.14.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Step 1: Gathering Data
# Let’s assume you have a list of sentences as your dataset:

# %%
data = ["This is the first sentence.", "Here's the second sentence.", "Finally, the third one."]

# %% [markdown]
# Step 2: Preprocessing Your Data
# Preprocessing your data is crucial for your model’s success:

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

tokenizer = Tokenizer()
tokenizer.fit_on_texts(data)
total_words = len(tokenizer.word_index) + 1

sequences = tokenizer.texts_to_sequences(data)

input_sequences = []
for sequence in sequences:
    for i in range(1, len(sequence)):
        n_gram_sequence = sequence[:i+1]
        input_sequences.append(n_gram_sequence)

max_sequence_length = max([len(seq) for seq in input_sequences])
input_sequences = pad_sequences(input_sequences, maxlen=max_sequence_length, padding='pre')

X = input_sequences[:, :-1]
y = input_sequences[:, -1]
# Out:
# /Users/shilpibhattacharyya/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %% [markdown]
# Step 3: Choosing a Generative Model Architecture

# %% [markdown]
# Let’s set up an RNN for text generation:

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(total_words, 64, input_length=max_sequence_length-1),
    tf.keras.layers.LSTM(100),
    tf.keras.layers.Dense(total_words, activation='softmax')
])

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# Step 4: Training Your Generative Model
# Time to train your model:

# %%
model.fit(X, y, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 1s 626ms/step - loss: 2.3944 - accuracy: 0.3000
# Epoch 2/100
# 1/1 [==============================] - 0s 4ms/step - loss: 2.3865 - accuracy: 0.4000
# Epoch 3/100
# 1/1 [==============================] - 0s 3ms/step - loss: 2.3785 - accuracy: 0.4000
# Epoch 4/100
# 1/1 [==============================] - 0s 3ms/step - loss: 2.3703 - accuracy: 0.4000
# Epoch 5/100
# 1/1 [==============================] - 0s 3ms/step - loss: 2.3618 - accuracy: 0.4000
# Epoch 6/100
# 1/1 [==============================] - 0s 4ms/step - loss: 2.3529 - accuracy: 0.4000
# Epoch 7/100
# 1/1 [==============================] - 0s 4ms/step - loss: 2.3435 - accuracy: 0.4000
# Epoch 8/100
# 1/1 [==============================] - 0s 3ms/step - loss: 2.3335 - accuracy: 0.4000
# Epoch 9/100
# 1/1 [==============================] - 0s 3ms/step - loss: 2.3228 - accuracy: 0.4000
# Epoch 10/100
# 1/1 [==============================] - 0s 4ms/step - loss: 2.3113 - accuracy: 0.4000
# Epoch 11/100
# 1/1 [==============================] - 0s 4ms/step - loss: 2.2989 - accuracy: 0.4000
# Epoch 12/100
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2853 - accuracy: 0.4000
# Epoch 13/100
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2706 - accuracy: 0.4000
# Epoch 14/100
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2545 - accuracy: 0.4000
# Epoch 15/100
# 1/1 [==============================] - 0s 4ms/step - loss: 2.2369 - accuracy: 0.4000
# Epoch 16/100
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2175 - accuracy: 0.4000
# Epoch 17/100
# 1/1 [==============================] - 0s 5ms/step - loss: 2.1963 - accuracy: 0.4000
# Epoch 18/100
# 1/1 [==============================] - 0s 4ms/step - loss: 2.1730 - accuracy: 0.4000
# Epoch 19/100
# 1/1 [==============================] - 0s 4ms/step - loss: 2.1474 - accuracy: 0.4000
# Epoch 20/100
# 1/1 [==============================] - 0s 4ms/step - loss: 2.1195 - accuracy: 0.4000
# Epoch 21/100
# 1/1 [==============================] - 0s 4ms/step - loss: 2.0892 - accuracy: 0.4000
# Epoch 22/100
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0565 - accuracy: 0.3000
# Epoch 23/100
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0216 - accuracy: 0.3000
# Epoch 24/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9850 - accuracy: 0.3000
# Epoch 25/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.9476 - accuracy: 0.3000
# Epoch 26/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9109 - accuracy: 0.3000
# Epoch 27/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.8768 - accuracy: 0.3000
# Epoch 28/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.8479 - accuracy: 0.3000
# Epoch 29/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.8259 - accuracy: 0.3000
# Epoch 30/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.8105 - accuracy: 0.3000
# Epoch 31/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.7979 - accuracy: 0.3000
# Epoch 32/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.7832 - accuracy: 0.3000
# Epoch 33/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.7632 - accuracy: 0.3000
# Epoch 34/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.7373 - accuracy: 0.4000
# Epoch 35/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.7076 - accuracy: 0.4000
# Epoch 36/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.6766 - accuracy: 0.4000
# Epoch 37/100
# 1/1 [==============================] - 0s 17ms/step - loss: 1.6464 - accuracy: 0.4000
# Epoch 38/100
# 1/1 [==============================] - 0s 8ms/step - loss: 1.6182 - accuracy: 0.5000
# Epoch 39/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.5919 - accuracy: 0.5000
# Epoch 40/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5667 - accuracy: 0.5000
# Epoch 41/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5416 - accuracy: 0.5000
# Epoch 42/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.5154 - accuracy: 0.5000
# Epoch 43/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.4873 - accuracy: 0.5000
# Epoch 44/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.4568 - accuracy: 0.5000
# Epoch 45/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.4240 - accuracy: 0.5000
# Epoch 46/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.3893 - accuracy: 0.5000
# Epoch 47/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.3531 - accuracy: 0.5000
# Epoch 48/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.3164 - accuracy: 0.5000
# Epoch 49/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.2796 - accuracy: 0.5000
# Epoch 50/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.2433 - accuracy: 0.5000
# Epoch 51/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.2072 - accuracy: 0.5000
# Epoch 52/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.1711 - accuracy: 0.5000
# Epoch 53/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.1345 - accuracy: 0.5000
# Epoch 54/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.0974 - accuracy: 0.5000
# Epoch 55/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.0600 - accuracy: 0.5000
# Epoch 56/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.0231 - accuracy: 0.6000
# Epoch 57/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9870 - accuracy: 0.6000
# Epoch 58/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9517 - accuracy: 0.6000
# Epoch 59/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.9167 - accuracy: 0.7000
# Epoch 60/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.8818 - accuracy: 0.7000
# Epoch 61/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.8467 - accuracy: 0.8000
# Epoch 62/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.8119 - accuracy: 0.8000
# Epoch 63/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7780 - accuracy: 0.8000
# Epoch 64/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7448 - accuracy: 0.8000
# Epoch 65/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.7121 - accuracy: 0.9000
# Epoch 66/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6794 - accuracy: 0.9000
# Epoch 67/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6469 - accuracy: 0.9000
# Epoch 68/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6150 - accuracy: 0.9000
# Epoch 69/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5844 - accuracy: 0.9000
# Epoch 70/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5550 - accuracy: 0.9000
# Epoch 71/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5265 - accuracy: 0.9000
# Epoch 72/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4986 - accuracy: 0.9000
# Epoch 73/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4718 - accuracy: 0.9000
# Epoch 74/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4467 - accuracy: 0.9000
# Epoch 75/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4231 - accuracy: 0.9000
# Epoch 76/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.4007 - accuracy: 0.9000
# Epoch 77/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3793 - accuracy: 0.9000
# Epoch 78/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3592 - accuracy: 0.9000
# Epoch 79/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3406 - accuracy: 0.9000
# Epoch 80/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3233 - accuracy: 0.9000
# Epoch 81/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3069 - accuracy: 0.9000
# Epoch 82/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2913 - accuracy: 0.9000
# Epoch 83/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2768 - accuracy: 0.9000
# Epoch 84/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2633 - accuracy: 0.9000
# Epoch 85/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2505 - accuracy: 0.9000
# Epoch 86/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2384 - accuracy: 0.9000
# Epoch 87/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2269 - accuracy: 0.9000
# Epoch 88/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2161 - accuracy: 0.9000
# Epoch 89/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2058 - accuracy: 0.9000
# Epoch 90/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1959 - accuracy: 0.9000
# Epoch 91/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1865 - accuracy: 0.9000
# Epoch 92/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1776 - accuracy: 1.0000
# Epoch 93/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1691 - accuracy: 1.0000
# Epoch 94/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1610 - accuracy: 1.0000
# Epoch 95/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1534 - accuracy: 1.0000
# Epoch 96/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1460 - accuracy: 1.0000
# Epoch 97/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1389 - accuracy: 1.0000
# Epoch 98/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1320 - accuracy: 1.0000
# Epoch 99/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1254 - accuracy: 1.0000
# Epoch 100/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1190 - accuracy: 1.0000

# %% [markdown]
# Step 5: Generating Text
#
# Now, you can generate text using your trained model:

# %%
seed_text = "You,"
next_words = 10

for _ in range(next_words):
    token_list = tokenizer.texts_to_sequences([seed_text])[0]
    token_list = pad_sequences([token_list], maxlen=max_sequence_length-1, padding='pre')
    #predicted = model.predict_classes(token_list, verbose=0)

    predict_x=model.predict(token_list) 
    classes_x=np.argmax(predict_x,axis=1)
    
    output_word = ""
    for word, index in tokenizer.word_index.items():
        if index == classes_x:
            output_word = word
            break
    seed_text += " " + output_word

print(seed_text)
# Out:
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 6ms/step
# You, the the second sentence sentence sentence sentence sentence sentence sentence

# %% [markdown]
# Reference: https://www.mltut.com/how-to-build-generative-ai-model/
